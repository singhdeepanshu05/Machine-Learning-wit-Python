# %%
import pandas as pd

# %% [markdown]
# - https://drive.google.com/file/d/1MbN1VFgA0Ue_-wvzvxXcNVnVnBw9PtSv/view?usp=sharing

# %%
data = pd.read_csv('Mobilephone_data_final - ndtv_data_final.csv')

# %%
data
# Out:
#       Sr. No.                            Name     Brand  \
# 0           0  OnePlus 7T Pro McLaren Edition   OnePlus
# 1           1                   Realme X2 Pro    Realme
# 2           2               iPhone 11 Pro Max     Apple
# 3           3                       iPhone 11     Apple
# 4           4                    LG G8X ThinQ        LG
# ...       ...                             ...       ...
# 1354     1354                   Intex Aqua A2     Intex
# 1355     1355     Videocon Infinium Z51 Nova+  Videocon
# 1356     1356                   Intex Aqua Y4     Intex
# 1357     1357                 iBall Andi4 B20     iBall
# 1358     1358             iBall Andi Avonte 5     iBall
#
#                        Model  Battery capacity (mAh)  Screen size (inches)  \
# 0     7T Pro McLaren Edition                    4085                  6.67
# 1                     X2 Pro                    4000                  6.50
# ...

# %%
data.shape
# Out:
# (1359, 22)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1359 entries, 0 to 1358
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Sr. No.                 1359 non-null   int64
#  1   Name                    1359 non-null   object
#  2   Brand                   1359 non-null   object
#  3   Model                   1359 non-null   object
#  4   Battery capacity (mAh)  1359 non-null   int64
#  5   Screen size (inches)    1359 non-null   float64
#  6   Touchscreen             1359 non-null   object
#  7   Resolution x            1359 non-null   int64
#  8   Resolution y            1359 non-null   int64
#  9   Processor               1359 non-null   int64
#  10  RAM (MB)                1359 non-null   int64
#  11  Internal storage (GB)   1359 non-null   float64
#  12  Rear camera             1359 non-null   float64
#  13  Front camera            1359 non-null   float64
# ...

# %%
data.isnull().sum()
# Out:
# Sr. No.                   0
# Name                      0
# Brand                     0
# Model                     0
# Battery capacity (mAh)    0
# Screen size (inches)      0
# Touchscreen               0
# Resolution x              0
# Resolution y              0
# Processor                 0
# RAM (MB)                  0
# Internal storage (GB)     0
# Rear camera               0
# Front camera              0
# Operating system          0
# Wi-Fi                     0
# Bluetooth                 0
# GPS                       0
# Number of SIMs            0
# 3G                        0
# 4G/ LTE                   0
# Price                     0
# dtype: int64

# %%
data.describe()
# Out:
#            Sr. No.  Battery capacity (mAh)  Screen size (inches)  \
# count  1359.000000             1359.000000           1359.000000
# mean    679.000000             2938.489330              5.291310
# std     392.453819              873.514133              0.671357
# min       0.000000             1010.000000              2.400000
# 25%     339.500000             2300.000000              5.000000
# 50%     679.000000             3000.000000              5.200000
# 75%    1018.500000             3500.000000              5.700000
# max    1358.000000             6000.000000              7.300000
#
#        Resolution x  Resolution y    Processor      RAM (MB)  \
# count   1359.000000   1359.000000  1359.000000   1359.000000
# mean     811.543046   1490.777778     5.551141   2488.777778
# std      270.707271    557.780120     2.196562   1664.440386
# min      240.000000    320.000000     1.000000     64.000000
# 25%      720.000000   1280.000000     4.000000   1000.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Q1. Plot a scatter chart between 'Resolution x' and 'Resolution y'.

# %%
sns.scatterplot(x = data['Resolution x'], y = data['Resolution y'])
# Out:
# <AxesSubplot:xlabel='Resolution x', ylabel='Resolution y'>

# %% [markdown]
# Q2. Plot a bar chart between brand and number of mobile of that brand.

# %%
plt.figure(figsize=(70,5))
plt.hist(data['Brand'])
# Out:
# (array([309., 180., 155., 157., 206., 199.,  57.,  49.,  37.,  10.]),
#  array([ 0. ,  7.5, 15. , 22.5, 30. , 37.5, 45. , 52.5, 60. , 67.5, 75. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Q3. Plot a chart between Brand and their median price

# %%
plt.figure(figsize=(70,10))
plt.plot(data.groupby('Brand')['Price'].median())

# %%
data.groupby('Brand')['Price'].median()
# Out:
# Brand
# 10.or       4999.0
# Acer        6470.0
# Alcatel     9499.0
# Apple      36999.0
# Aqua        4599.0
#             ...
# Zopo        4743.0
# Zuk        29124.0
# iBall       3999.0
# iVoomi      4070.0
# mPhone      6949.0
# Name: Price, Length: 76, dtype: float64

# %% [markdown]
# Q4. Plot a box plot chart of price

# %%
sns.boxplot(y = data['Price'], data = data)
# Out:
# <AxesSubplot:ylabel='Price'>

# %% [markdown]
# Q5. Plot a scatterr chart between 'Battery capacity (mAh)' and 'Price' and give the color on 'Number of SIMs'.

# %%
data['Number of SIMs'].unique()
# Out:
# array([2, 1, 3], dtype=int64)

# %%
data[data['Number of SIMs'] ==3]
# Out:
#                Name    Brand   Model  Battery capacity (mAh)  \
# 508  Coolpad Mega 3  Coolpad  Mega 3                    3050
#
#      Screen size (inches) Touchscreen  Resolution x  Resolution y  Processor  \
# 508                   5.5         Yes           720          1080          4
#
#      RAM (MB)  ...  Rear camera  Front camera  Operating system Wi-Fi  \
# 508      2000  ...          8.0           8.0           Android   Yes
#
#     Bluetooth GPS Number of SIMs   3G 4G/ LTE Price
# 508       Yes  No              3  Yes     Yes  4590
#
# [1 rows x 21 columns]

# %%
colors={1:'tab:green',2:'tab:blue',3:'tab:red'}
plt.scatter(x= data['Battery capacity (mAh)'], y  = data['Price'],c = data['Number of SIMs'].map(colors))
plt.xlabel("Battery capacity (mAh")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
sns.scatterplot(x= data['Battery capacity (mAh)'], y  = data['Price'], hue = data['Number of SIMs'],palette = 'deep' )
# Out:
# <AxesSubplot:xlabel='Battery capacity (mAh)', ylabel='Price'>

# %% [markdown]
# Q6. Draw the correaltion heat map

# %%
data['Sr. No.']
# Out:
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 1354    1354
# 1355    1355
# 1356    1356
# 1357    1357
# 1358    1358
# Name: Sr. No., Length: 1359, dtype: int64

# %%
sns.heatmap(data.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Q7. Draw a distribution chart for price

# %%
plt.figure(figsize=(50,10))
plt.hist(data['Price'])
# Out:
# (array([1.166e+03, 1.240e+02, 3.200e+01, 2.400e+01, 7.000e+00, 3.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 2.000e+00]),
#  array([   494. ,  17943.6,  35393.2,  52842.8,  70292.4,  87742. ,
#         105191.6, 122641.2, 140090.8, 157540.4, 174990. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Q8. Create a function which can encode the 'Wi-Fi' and 'Bluetooth' column values from Yes to 1 and No to 0.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
data['Wi-Fi'] = le.fit_transform(data['Wi-Fi'])

# %%
data['Bluetooth'] = le.fit_transform(data['Bluetooth'])

# %%
data[data['Bluetooth'] == 0]
# Out:
#                        Name      Brand          Model  Battery capacity (mAh)  \
# 603      Alcatel Pixi 4 (5)    Alcatel     Pixi 4 (5)                    2000
# 642                Itel A46       Itel            A46                    2400
# 744                Lava Z91       Lava            Z91                    3000
# 789           Panasonic P91  Panasonic            P91                    2500
# 815         Swipe Elite Pro      Swipe      Elite Pro                    2500
# 824                 10.or G      10.or              G                    4000
# 857         Swipe Neo Power      Swipe      Neo Power                    2500
# 858           Meizu M6 Note      Meizu        M6 Note                    4000
# 883             Meizu Pro 7      Meizu          Pro 7                    3000
# 970   Samsung Galaxy J2 Ace    Samsung  Galaxy J2 Ace                    2600
# 983           Panasonic P88  Panasonic            P88                    2600
# ...

# %% [markdown]
# Q9. Find the max value of all numerical columns.

# %%
(data.columns).size
# Out:
# 21

# %%
for i in range((data.columns).size):
    if data[i] == data[i]:
        data[i].max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# Q10. Filter the OnePlus Brand Mobile and reset the index.

# %%
data[data['Brand'] == 'OnePlus'].reset_index()
# Out:
#     index                            Name    Brand                   Model  \
# 0       0  OnePlus 7T Pro McLaren Edition  OnePlus  7T Pro McLaren Edition
# 1       5                      OnePlus 7T  OnePlus                      7T
# 2       6                  OnePlus 7T Pro  OnePlus                  7T Pro
# 3      13                   OnePlus 7 Pro  OnePlus                   7 Pro
# 4      20                      OnePlus 6T  OnePlus                      6T
# 5      31                       OnePlus 6  OnePlus                       6
# 6      48                      OnePlus 3T  OnePlus                      3T
# 7      54                       OnePlus 3  OnePlus                       3
# 8      98                       OnePlus 7  OnePlus                       7
# 9     138                      OnePlus 5T  OnePlus                      5T
# 10    159                       OnePlus 5  OnePlus                       5
# ...
